# %%
# The imports

from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
# The usual starting point

load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model
# It is that easy to instantiate an Agent!
# instructions = system prompt
agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-4o-mini")

# %%
agent

# %%
result = Runner.run(agent, "Tell me a joke about Autonomous AI agents")
print(result) # Coroutine object!

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

# Use trace() - Record the interaction under the header "Telling a joke"
# useful in OpenAI tracing (Traces tab in the dev console)
with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the autonomous AI agent bring a ladder to the bar?
#
# Because it heard the drinks were on the house!
# C:\Users\Alessandro\AppData\Local\Temp\ipykernel_26448\1259425552.py:4: RuntimeWarning: coroutine 'Runner.run' was never awaited
#   result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
# ...

# %%
# Python Promise.all()
results = await asyncio.gather(
    thing_one(),
    thing_two(),
    thing_three()
)
